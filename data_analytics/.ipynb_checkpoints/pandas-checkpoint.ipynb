# %%
# what we can do with pandas
# can create a data frame with list of dictionaries
# can create a data frame from csv/json/yaml/ any other excel format, or any other text files.
# can create a data frame from sql query
# can read data from web page
import pandas as pd
df = pd.read_html("https://www.w3schools.com/html/html_tables.asp?pStoreID=hp_education%27[0]%27")

# %%
print(df)
# Out:
# [                        Company           Contact  Country
# 0           Alfreds Futterkiste      Maria Anders  Germany
# 1    Centro comercial Moctezuma   Francisco Chang   Mexico
# 2                  Ernst Handel     Roland Mendel  Austria
# 3                Island Trading     Helen Bennett       UK
# 4  Laughing Bacchus Winecellars   Yoshi Tannamuri   Canada
# 5  Magazzini Alimentari Riuniti  Giovanni Rovelli    Italy,           Tag                                        Description
# 0     <table>                                    Defines a table
# 1        <th>                   Defines a header cell in a table
# 2        <tr>                           Defines a row in a table
# 3        <td>                          Defines a cell in a table
# 4   <caption>                            Defines a table caption
# 5  <colgroup>  Specifies a group of one or more columns in a ...
# 6       <col>  Specifies column properties for each column wi...
# ...

# %%
for table in df:
    print(table)
    print("*"*20)
# Out:
#                         Company           Contact  Country
# 0           Alfreds Futterkiste      Maria Anders  Germany
# 1    Centro comercial Moctezuma   Francisco Chang   Mexico
# 2                  Ernst Handel     Roland Mendel  Austria
# 3                Island Trading     Helen Bennett       UK
# 4  Laughing Bacchus Winecellars   Yoshi Tannamuri   Canada
# 5  Magazzini Alimentari Riuniti  Giovanni Rovelli    Italy
# ********************
#           Tag                                        Description
# 0     <table>                                    Defines a table
# 1        <th>                   Defines a header cell in a table
# 2        <tr>                           Defines a row in a table
# 3        <td>                          Defines a cell in a table
# 4   <caption>                            Defines a table caption
# 5  <colgroup>  Specifies a group of one or more columns in a ...
# 6       <col>  Specifies column properties for each column wi...
# ...

# %%
import requests

# %%
resp = requests.get("https://www.w3schools.com/html/html_tables.asp?pStoreID=hp_education%27[0]%27")

# %%
print(resp.json())
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\requests\models.py:974, in Response.json(self, **kwargs)
#     973 try:
# --> 974     return complexjson.loads(self.text, **kwargs)
#     975 except JSONDecodeError as e:
#     976     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     977     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~\anaconda3\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# ...

# %%
print(resp.text)
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
# <head>
# <title>HTML Tables</title>
# <meta charset="utf-8">
# <meta name="viewport" content="width=device-width, initial-scale=1">
# <meta name="title" property="og:title" content="W3Schools.com">
# <meta name="Keywords" content="HTML, Python, CSS, SQL, JavaScript, How to, PHP, Java, C, C++, C#, jQuery, Bootstrap, Colors, W3.CSS, XML, MySQL, Icons, NodeJS, React, Graphics, Angular, R, AI, Git, Data Science, Code Game, Tutorials, Programming, Web Development, Training, Learning, Quiz, Exercises, Courses, Lessons, References, Examples, Learn to code, Source code, Demos, Tips, Website">
# <meta name="Description" content="Well organized and easy to understand Web building tutorials with lots of examples of how to use HTML, CSS, JavaScript, SQL, Python, PHP, Bootstrap, Java, XML and more.">
# <meta property="og:image" content="https://www.w3schools.com/images/w3schools_logo_436_2.png">
# <meta property="og:image:type" content="image/png">
# ...

# %%
df = pd.read_clipboard()

# %%
print(df)
# Out:
#    id    name  salary
# 0   1     sam  124234
# 1   2  saresh  345345

# %%
df = pd.read_csv("2015-summary.csv")

# %%
print(df)
# Out:
#                      DEST_COUNTRY_NAME    ORIGIN_COUNTRY_NAME  count
# 0                        United States                Romania     15
# 1                        United States                Croatia      1
# 2                        United States                Ireland    344
# 3                                Egypt          United States     15
# 4                        United States                  India     62
# ..                                 ...                    ...    ...
# 251                      United States  Saint Kitts and Nevis    145
# 252                            Uruguay          United States     43
# 253                      United States                  Haiti    225
# 254  Bonaire, Sint Eustatius, and Saba          United States     58
# 255                             Greece          United States     30
#
# [256 rows x 3 columns]

# %%
df.columns
# Out:
# Index(['DEST_COUNTRY_NAME', 'ORIGIN_COUNTRY_NAME', 'count'], dtype='object')

# %%
print(df['DEST_COUNTRY_NAME'])
# Out:
# 0                          United States
# 1                          United States
# 2                          United States
# 3                                  Egypt
# 4                          United States
#                      ...
# 251                        United States
# 252                              Uruguay
# 253                        United States
# 254    Bonaire, Sint Eustatius, and Saba
# 255                               Greece
# Name: DEST_COUNTRY_NAME, Length: 256, dtype: object

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
print(type(df['DEST_COUNTRY_NAME']))
# Out:
# <class 'pandas.core.series.Series'>

# %%
print(df['DEST_COUNTRY_NAME'].values)
# Out:
# ['United States' 'United States' 'United States' 'Egypt' 'United States'
#  'United States' 'United States' 'Costa Rica' 'Senegal' 'Moldova'
#  'United States' 'United States' 'Guyana' 'Malta' 'Anguilla' 'Bolivia'
#  'United States' 'Algeria' 'Turks and Caicos Islands' 'United States'
#  'Saint Vincent and the Grenadines' 'Italy' 'United States'
#  'United States' 'Pakistan' 'United States' 'Iceland' 'Marshall Islands'
#  'Luxembourg' 'Honduras' 'The Bahamas' 'United States' 'El Salvador'
#  'Samoa' 'United States' 'Switzerland' 'United States' 'Sint Maarten'
#  'Hong Kong' 'Trinidad and Tobago' 'Latvia' 'United States' 'Suriname'
#  'Mexico' 'United States' 'Ecuador' 'United States' 'United States'
#  'United States' 'United States' 'Colombia' 'United States'
#  'United States' 'Norway' 'United States' 'United States' 'Thailand'
#  'United States' 'Venezuela' 'United States' 'United States' 'Panama'
#  'Antigua and Barbuda' 'United States' 'Morocco' 'United States'
# ...

# %%
import numpy as np
ar1 = np.array(df['DEST_COUNTRY_NAME'].values)
col1 = df['DEST_COUNTRY_NAME']
print(type(ar1))
print(type(col1))
# Out:
# <class 'numpy.ndarray'>
# <class 'pandas.core.series.Series'>

# %%
print(ar1)
# Out:
# ['United States' 'United States' 'United States' 'Egypt' 'United States'
#  'United States' 'United States' 'Costa Rica' 'Senegal' 'Moldova'
#  'United States' 'United States' 'Guyana' 'Malta' 'Anguilla' 'Bolivia'
#  'United States' 'Algeria' 'Turks and Caicos Islands' 'United States'
#  'Saint Vincent and the Grenadines' 'Italy' 'United States'
#  'United States' 'Pakistan' 'United States' 'Iceland' 'Marshall Islands'
#  'Luxembourg' 'Honduras' 'The Bahamas' 'United States' 'El Salvador'
#  'Samoa' 'United States' 'Switzerland' 'United States' 'Sint Maarten'
#  'Hong Kong' 'Trinidad and Tobago' 'Latvia' 'United States' 'Suriname'
#  'Mexico' 'United States' 'Ecuador' 'United States' 'United States'
#  'United States' 'United States' 'Colombia' 'United States'
#  'United States' 'Norway' 'United States' 'United States' 'Thailand'
#  'United States' 'Venezuela' 'United States' 'United States' 'Panama'
#  'Antigua and Barbuda' 'United States' 'Morocco' 'United States'
# ...

# %%
import numpy as np
import pandas as pd
ar1 = np.array(df['DEST_COUNTRY_NAME'].values)
ser1 = pd.Series(df['DEST_COUNTRY_NAME'], index=[i+3000 for i in range(len(ar1))])
print(type(ar1))
print(type(col1))
# Out:
# <class 'numpy.ndarray'>
# <class 'pandas.core.series.Series'>

# %%
print(ser1)
# Out:
# 3000    NaN
# 3001    NaN
# 3002    NaN
# 3003    NaN
# 3004    NaN
#        ...
# 3251    NaN
# 3252    NaN
# 3253    NaN
# 3254    NaN
# 3255    NaN
# Name: DEST_COUNTRY_NAME, Length: 256, dtype: object

# %%
emp_ids = ["a"+str(i) for i in range(10)]
print(emp_ids)
# Out:
# ['a0', 'a1', 'a2', 'a3', 'a4', 'a5', 'a6', 'a7', 'a8', 'a9']

# %%
import faker
import random
fak = faker.Faker()
names = [fak.name() for i in range(10)]
emp_ids = ["a"+str(i) for i in range(10)]
salaries = [random.randint(2000,3000) for i in range(10)]
print(names)
print(emp_ids)
print(salaries)
# Out:
# ['Brooke Lopez', 'Wayne Robinson', 'Donna Proctor', 'Danny Coleman', 'Lisa Small', 'Brian Mann', 'Abigail Mathews', 'Dr. Jason Wilson', 'Emily Snow', 'Bradley Barker']
# ['a0', 'a1', 'a2', 'a3', 'a4', 'a5', 'a6', 'a7', 'a8', 'a9']
# [2412, 2779, 2560, 2088, 2521, 2940, 2230, 2598, 2005, 2041]

# %%
import faker
import random
fak = faker.Faker()
names = [fak.name() for i in range(10)]
emp_ids = ["a"+str(i) for i in range(10)]
salaries = [random.randint(2000,3000) for i in range(10)]
df = pd.DataFrame({"name":names,"emp_id":emp_ids,"salary":salaries})
print(df)
# Out:
#                name emp_id  salary
# 0   Rebecca Hartman     a0    2423
# 1        Chad Smith     a1    2154
# 2  Kenneth Campbell     a2    2629
# 3     Rhonda Cannon     a3    2347
# 4       Melvin King     a4    2064
# 5    Melissa Thomas     a5    2796
# 6        James Hunt     a6    2109
# 7    Cheryl Vincent     a7    2464
# 8     Robert Bishop     a8    2285
# 9      Debbie Mills     a9    2838

# %%
import faker
import random
fak = faker.Faker()
data = []
for i in range(10):
    data.append({"name":fak.name(), "emp_id":"a"+str(i), "salary":random.randint(2000,3000)})
print(data)
df = pd.DataFrame(data)
print(df)
# Out:
# [{'name': 'Robert Richardson', 'emp_id': 'a0', 'salary': 2616}, {'name': 'Lisa Harvey', 'emp_id': 'a1', 'salary': 2604}, {'name': 'Eugene Baker', 'emp_id': 'a2', 'salary': 2124}, {'name': 'Lacey Graves', 'emp_id': 'a3', 'salary': 2754}, {'name': 'Richard Ramirez', 'emp_id': 'a4', 'salary': 2782}, {'name': 'Rebecca Brooks', 'emp_id': 'a5', 'salary': 2763}, {'name': 'Pamela Preston', 'emp_id': 'a6', 'salary': 2696}, {'name': 'Cindy Young', 'emp_id': 'a7', 'salary': 2149}, {'name': 'Stacey Monroe', 'emp_id': 'a8', 'salary': 2800}, {'name': 'Megan Garrett MD', 'emp_id': 'a9', 'salary': 2513}]
#                 name emp_id  salary
# 0  Robert Richardson     a0    2616
# 1        Lisa Harvey     a1    2604
# 2       Eugene Baker     a2    2124
# 3       Lacey Graves     a3    2754
# 4    Richard Ramirez     a4    2782
# 5     Rebecca Brooks     a5    2763
# 6     Pamela Preston     a6    2696
# 7        Cindy Young     a7    2149
# 8      Stacey Monroe     a8    2800
# ...

# %%
import pandas as pd
import psycopg2
con = psycopg2.connect(host="localhost", user="postgres",password="postgres",port=5432,database="bigdata")
df = pd.read_sql("select * from employee limit 100",con)
print(df)
# Out:
#     emp_id first_name  last_name  dept_id   hire_date  \
# 0        1       Chad     Thomas       49  2017-06-28
# 1        2      Scott    Hampton       44  2017-09-24
# 2        3      James  Rodriguez       14  2015-12-26
# 3        4    Patrick   Williams       24  2024-11-27
# 4        5   Kimberly  Gutierrez       45  2017-10-13
# ..     ...        ...        ...      ...         ...
# 95      96       Todd   Gonzalez        9  2015-10-02
# 96      97      Sarah     Brooks       24  2022-02-17
# 97      98    Jessica      Jones       26  2020-04-09
# 98      99     Joseph  Patterson       24  2020-02-23
# 99     100      Mandy   Mitchell       28  2023-02-26
#
#                             email
# 0    rachelmclaughlin@example.com
# 1             thanson@example.com
# 2             grace66@example.net
# 3        grosscynthia@example.net
# 4            amanda91@example.org
# ..                            ...
# 95            kelly02@example.net
# ...

# %%
import pandas as pd
import psycopg2
con = psycopg2.connect(host="localhost", user="postgres",password="postgres",port=5432,database="bigdata")
df = pd.read_sql_table(table_name="employee",con=con)
print(df)
# Out:
# C:\Users\Navya\AppData\Local\Temp\ipykernel_13464\1743185423.py:4: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_table(table_name="employee",con=con)
# ---------------------------------------------------------------------------
# SyntaxError                               Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\io\sql.py:2674, in SQLiteDatabase.execute(self, sql, params)
#    2673 try:
# -> 2674     cur.execute(sql, *args)
#    2675     return cur
#
# SyntaxError: syntax error at or near ";"
# LINE 8:             AND name=?;
#                               ^
#
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[38], line 4
#       2 import psycopg2
# ...

# %%
import pandas as pd
import psycopg2
con = psycopg2.connect(host="localhost", user="postgres",password="postgres",port=5432,database="bigdata")
cur = con.cursor()
df = pd.read_sql_table("employee",cur)
print(df)
# Out:
# C:\Users\Navya\AppData\Local\Temp\ipykernel_13464\555461750.py:5: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_table("employee",cur)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[39], line 5
#       3 con = psycopg2.connect(host="localhost", user="postgres",password="postgres",port=5432,database="bigdata")
#       4 cur = con.cursor()
# ----> 5 df = pd.read_sql_table("employee",cur)
#       6 print(df)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\sql.py:385, in read_sql_table(table_name, con, schema, index_col, coerce_float, parse_dates, columns, chunksize, dtype_backend)
#     382 assert dtype_backend is not lib.no_default
# ...

# %%
import pandas as pd
import psycopg2
con = psycopg2.connect(host="localhost", user="postgres",password="postgres",port=5432,database="bigdata")
df = pd.read_sql_table("select * from employee",con)
print(df)
# Out:
# C:\Users\Navya\AppData\Local\Temp\ipykernel_13464\2836385342.py:4: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_table("select * from employee",con)
# ---------------------------------------------------------------------------
# SyntaxError                               Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\io\sql.py:2674, in SQLiteDatabase.execute(self, sql, params)
#    2673 try:
# -> 2674     cur.execute(sql, *args)
#    2675     return cur
#
# SyntaxError: syntax error at or near ";"
# LINE 8:             AND name=?;
#                               ^
#
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[41], line 4
#       2 import psycopg2
# ...

# %%
import pandas as pd
import psycopg2
con = psycopg2.connect(host="localhost", user="postgres",password="postgres",port=5432,database="bigdata")
df = pd.read_sql("select * from salary",con)
# Out:
# C:\Users\Navya\AppData\Local\Temp\ipykernel_13464\1478333825.py:4: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql("select * from salary",con)

# %%
print(len(df))
# Out:
# 31097480

# %%
1550/1024
# Out:
# 1.513671875

# %%
import pandas as pd
import psycopg2
con = psycopg2.connect(host="localhost", user="postgres",password="postgres",port=5432,database="bigdata")
df = pd.read_sql("select sum(amount) from salary",con)
print(df)
# Out:
# C:\Users\Navya\AppData\Local\Temp\ipykernel_13464\604076851.py:4: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql("select sum(amount) from salary",con)
#             sum
# 0  2.798801e+11

# %%
import numpy as np
print(np.nan)
# Out:
# nan

# %%
np.nan == np.nan
# Out:
# False

# %%
ar1 = np.array([1,2,3,4])
ar2 = np.array([1,2,3,4])
print(ar1==ar2)
# Out:
# [ True  True  True  True]

# %%
ar1 = np.array([1,2,3,4,np.nan])
ar2 = np.array([1,2,3,4, np.nan])
print(ar1==ar2)
# Out:
# [ True  True  True  True False]

# %%
np.sum(ar1)
# Out:
# nan

# %%
salaries = [123,456,789]
# e1,e2,e3
import numpy as np
sal_array = np.array(salaries)
given_salaries = [456,123,789]
g_sal_array = np.array(given_salaries)
print(g_sal_array==sal_array)
# Out:
# [False False  True]

# %%
import pandas as pd
ser1 = pd.Series([123,456,789], index=["e1","e2","e3"])
print(ser1)
# Out:
# e1    123
# e2    456
# e3    789
# dtype: int64

# %%
import pandas as pd
ser1 = pd.Series([123,456,789], index=["e1","e2","e3"])
print(ser1)
ser2 = pd.Series([456,123,789], index=["e2","e1","e3"])
print(ser2)
print(ser1==ser2)
# Out:
# e1    123
# e2    456
# e3    789
# dtype: int64
# e2    456
# e1    123
# e3    789
# dtype: int64
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 6
#       4 ser2 = pd.Series([456,123,789], index=["e2","e1","e3"])
#       5 print(ser2)
# ----> 6 print(ser1==ser2)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\arraylike.py:40, in OpsMixin.__eq__(self, other)
#      38 @unpack_zerodim_and_defer("__eq__")
#      39 def __eq__(self, other):
# ---> 40     return self._cmp_method(other, operator.eq)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:6114, in Series._cmp_method(self, other, op)
# ...

# %%
import pandas as pd
ser1 = pd.Series([123,456,789], index=["e1","e2","e3"])
print(ser1)
ser2 = pd.Series([456,123,789], index=["e2","e1","e3"])
print(ser2)
print(ser1.equals(ser2))
# Out:
# e1    123
# e2    456
# e3    789
# dtype: int64
# e2    456
# e1    123
# e3    789
# dtype: int64
# False

# %%
import pandas as pd
ser1 = pd.Series([123,456,789], index=["e1","e2","e3"])
ser2 = pd.Series([456,123,789], index=["e2","e1","e3"])
print(ser1.equals(ser2))
# Out:
# False

# %%
print(ser1[0])
# Out:
# 123
# C:\Users\Navya\AppData\Local\Temp\ipykernel_8836\482371091.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(ser1[0])

# %%
print(ser1["e1"])
# Out:
# 123

# %%
import pandas as pd
ser1 = pd.Series([123,456,789], index=["e1","e2","e3"])
ser2 = pd.Series([456,123,789], index=["e2","e1","e3"])
print(ser1.index)
# Out:
# Index(['e1', 'e2', 'e3'], dtype='object')

# %%
import pandas as pd
ser1 = pd.Series([123,456,789], index=["e1","e2","e3"])
ser2 = pd.Series([456,123,789], index=["e2","e1","e3"])
print(ser1.index)
print(ser2.index)
# Out:
# Index(['e1', 'e2', 'e3'], dtype='object')
# Index(['e2', 'e1', 'e3'], dtype='object')

# %%
import pandas as pd
df1 = pd.DataFrame([123,456,789], index=["e1","e2","e3"], columns=['col1'])
df2 = pd.DataFrame([456,123,789], index=["e2","e1","e3"], columns=['col1'])
print(df1.equals(df2))
# Out:
# False

# %%
print(df1)
# Out:
#     col1
# e1   123
# e2   456
# e3   789

# %%
print(df2)
# Out:
#     col1
# e2   456
# e1   123
# e3   789

# %%
print(dir(pd))
# Out:
# ['ArrowDtype', 'BooleanDtype', 'Categorical', 'CategoricalDtype', 'CategoricalIndex', 'DataFrame', 'DateOffset', 'DatetimeIndex', 'DatetimeTZDtype', 'ExcelFile', 'ExcelWriter', 'Flags', 'Float32Dtype', 'Float64Dtype', 'Grouper', 'HDFStore', 'Index', 'IndexSlice', 'Int16Dtype', 'Int32Dtype', 'Int64Dtype', 'Int8Dtype', 'Interval', 'IntervalDtype', 'IntervalIndex', 'MultiIndex', 'NA', 'NaT', 'NamedAgg', 'Period', 'PeriodDtype', 'PeriodIndex', 'RangeIndex', 'Series', 'SparseDtype', 'StringDtype', 'Timedelta', 'TimedeltaIndex', 'Timestamp', 'UInt16Dtype', 'UInt32Dtype', 'UInt64Dtype', 'UInt8Dtype', '__all__', '__builtins__', '__cached__', '__doc__', '__docformat__', '__file__', '__git_version__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__version__', '_built_with_meson', '_config', '_is_numpy_dev', '_libs', '_pandas_datetime_CAPI', '_pandas_parser_CAPI', '_testing', '_typing', '_version_meson', 'annotations', 'api', 'array', 'arrays', 'bdate_range', 'compat', 'con
# ...

# %%
print(dir(df1))
# Out:
# ['T', '_AXIS_LEN', '_AXIS_ORDERS', '_AXIS_TO_AXIS_NUMBER', '_HANDLED_TYPES', '__abs__', '__add__', '__and__', '__annotations__', '__array__', '__array_priority__', '__array_ufunc__', '__arrow_c_stream__', '__bool__', '__class__', '__contains__', '__copy__', '__dataframe__', '__dataframe_consortium_standard__', '__deepcopy__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__divmod__', '__doc__', '__eq__', '__finalize__', '__floordiv__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__iand__', '__ifloordiv__', '__imod__', '__imul__', '__init__', '__init_subclass__', '__invert__', '__ior__', '__ipow__', '__isub__', '__iter__', '__itruediv__', '__ixor__', '__le__', '__len__', '__lt__', '__matmul__', '__mod__', '__module__', '__mul__', '__ne__', '__neg__', '__new__', '__nonzero__', '__or__', '__pandas_priority__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__'
# ...

# %%
import pandas as pd
df1 = pd.DataFrame([123,456,789], index=["e1","e2","e3"], columns=['col1'])
df2 = pd.DataFrame([456,123,789], index=["e2","e1","e3"], columns=['col1'])
print(df1 == df2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8836\1060687438.py in ?()
#       1 import pandas as pd
#       2 df1 = pd.DataFrame([123,456,789], index=["e1","e2","e3"], columns=['col1'])
#       3 df2 = pd.DataFrame([456,123,789], index=["e2","e1","e3"], columns=['col1'])
# ----> 4 print(df1 == df2)
#
# ~\anaconda3\Lib\site-packages\pandas\core\ops\common.py in ?(self, other)
#      72                     return NotImplemented
#      73
#      74         other = item_from_zerodim(other)
#      75
# ---> 76         return method(self, other)
#
# ~\anaconda3\Lib\site-packages\pandas\core\arraylike.py in ?(self, other)
#      38     @unpack_zerodim_and_defer("__eq__")
#      39     def __eq__(self, other):
# ---> 40         return self._cmp_method(other, operator.eq)
#
# ~\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, other, op)
# ...

# %%
import pandas as pd
df1 = pd.DataFrame([123,456,789], index=["e1","e2","e3"], columns=['col1'])
df2 = pd.DataFrame([456,123,789], index=["e2","e1","e3"], columns=['col1'])
print(df1.col1.equals(df2.col1))
# Out:
# False

# %%
df1.col1
# Out:
# e1    123
# e2    456
# e3    789
# Name: col1, dtype: int64

# %%
df1.col1.astype(str)
# Out:
# e1    123
# e2    456
# e3    789
# Name: col1, dtype: object

# %%
col1 = df1.col1.astype(str)

# %%
print(df1.col1)
# Out:
# e1    123
# e2    456
# e3    789
# Name: col1, dtype: int64

# %%
df1.col1.astype(bool)
# Out:
# e1    True
# e2    True
# e3    True
# Name: col1, dtype: bool

# %%
df1 = pd.DataFrame([123.32432,456.34256,789.53425], index=["e1","e2","e3"], columns=['col1'])
print(df1)
# Out:
#          col1
# e1  123.32432
# e2  456.34256
# e3  789.53425

# %%
for i in df1:
    print(i)
# Out:
# col1

# %%
for index, row in df1.iterrows():
    print(index, row)
# Out:
# e1 col1    123.32432
# Name: e1, dtype: float64
# e2 col1    456.34256
# Name: e2, dtype: float64
# e3 col1    789.53425
# Name: e3, dtype: float64

# %%
for index, row in df1.iterrows():
    print(index, row, type(row))
# Out:
# e1 col1    123.32432
# Name: e1, dtype: float64 <class 'pandas.core.series.Series'>
# e2 col1    456.34256
# Name: e2, dtype: float64 <class 'pandas.core.series.Series'>
# e3 col1    789.53425
# Name: e3, dtype: float64 <class 'pandas.core.series.Series'>

# %%
df1 = pd.DataFrame(zip([123.32432,456.34256,789.53425],[123.32432,456.34256,789.53425]), index=["e1","e2","e3"], columns=['col1', 'col2'])
for index, row in df1.iterrows():
    print(index, row, type(row))
# Out:
# e1 col1    123.32432
# col2    123.32432
# Name: e1, dtype: float64 <class 'pandas.core.series.Series'>
# e2 col1    456.34256
# col2    456.34256
# Name: e2, dtype: float64 <class 'pandas.core.series.Series'>
# e3 col1    789.53425
# col2    789.53425
# Name: e3, dtype: float64 <class 'pandas.core.series.Series'>

# %%
print(row)
# Out:
# col1    789.53425
# col2    789.53425
# Name: e3, dtype: float64

# %%
print(row.index)
# Out:
# Index(['col1', 'col2'], dtype='object')

# %%
new_col = []
df1 = pd.DataFrame(zip([123.32432,456.34256,789.53425],[123.32432,456.34256,789.53425]), index=["e1","e2","e3"], columns=['col1', 'col2'])
for index, row in df1.iterrows():
    new_col.append(round(row.col1, 2))
print(new_col)
# Out:
# [123.32, 456.34, 789.53]

# %%
new_col = []
df1 = pd.DataFrame(zip([123.32432,456.34256,789.53425],[123.32432,456.34256,789.53425]), index=["e1","e2","e3"], columns=['col1', 'col2'])
for index, row in df1.iterrows():
    new_col.append(round(row.col1, 2))
df1['col1']=new_col
print(df1)
# Out:
#       col1       col2
# e1  123.32  123.32432
# e2  456.34  456.34256
# e3  789.53  789.53425

# %%
df1 = pd.DataFrame(zip([123.32432,456.34256,789.53425],[123.32432,456.34256,789.53425]), index=["e1","e2","e3"], columns=['col1', 'col2'])
res = df1.col1.apply(lambda x:round(x,2))
print(res)
# Out:
# e1    123.32
# e2    456.34
# e3    789.53
# Name: col1, dtype: float64

# %%
 df1.col1.apply?
# Out:
# Signature:
# df1.col1.apply(
#     func: 'AggFuncType',
#     convert_dtype: 'bool | lib.NoDefault' = <no_default>,
#     args: 'tuple[Any, ...]' = (),
#     *,
#     by_row: "Literal[False, 'compat']" = 'compat',
#     **kwargs,
# ) -> 'DataFrame | Series'
# Docstring:
# Invoke function on values of Series.
#
# Can be ufunc (a NumPy function that applies to the entire Series)
# or a Python function that only works on single values.
#
# Parameters
# ----------
# func : function
#     Python function or NumPy ufunc to apply.
# convert_dtype : bool, default True
#     Try to find better dtype for elementwise function results. If
#     False, leave as dtype=object. Note that the dtype is always
#     preserved for some extension array dtypes, such as Categorical.
#
#     .. deprecated:: 2.1.0
#         ``convert_dtype`` has been deprecated. Do ``ser.astype(object).apply()``
#         instead if you want ``convert_dtype=False``.
# args : tuple
# ...

# %%
df1 = pd.DataFrame(zip([123.32432,456.34256,789.53425],[123.32432,456.34256,789.53425]), index=["e1","e2","e3"], columns=['col1', 'col2'])
res = df1.col1.apply(lambda x:round(x,2))
print(df1)
# Out:
#          col1       col2
# e1  123.32432  123.32432
# e2  456.34256  456.34256
# e3  789.53425  789.53425

# %%
df1 = pd.DataFrame(zip([123.32432,456.34256,789.53425],[123.32432,456.34256,789.53425]), index=["e1","e2","e3"], columns=['col1', 'col2'])
res = df1.col1.apply(lambda x:round(x,2), inplace=True)
print(df1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[43], line 2
#       1 df1 = pd.DataFrame(zip([123.32432,456.34256,789.53425],[123.32432,456.34256,789.53425]), index=["e1","e2","e3"], columns=['col1', 'col2'])
# ----> 2 res = df1.col1.apply(lambda x:round(x,2), inplace=True)
#       3 print(df1)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
# ...

# %%
df1 = pd.DataFrame(zip([123.32432,456.34256,789.53425],[123.32432,456.34256,789.53425]), index=["e1","e2","e3"], columns=['col1', 'col2'])
df1['col1'] = df1.col1.apply(lambda x:round(x,2))
print(df1)
# Out:
#       col1       col2
# e1  123.32  123.32432
# e2  456.34  456.34256
# e3  789.53  789.53425

# %%
print(df1.add([1,2]))
# Out:
#       col1       col2
# e1  124.32  125.32432
# e2  457.34  458.34256
# e3  790.53  791.53425

# %%
df2 = pd.DataFrame([{"col1":1,"col2":2}], index=["e4"])
df3 = df1.add(df2)
print(df3)
# Out:
#     col1  col2
# e1   NaN   NaN
# e2   NaN   NaN
# e3   NaN   NaN
# e4   NaN   NaN

# %%
df2 = pd.DataFrame([{"col1":1,"col2":2}], index=["e4"])
df3 = df1.add(df2, axis=0)
print(df3)
# Out:
#     col1  col2
# e1   NaN   NaN
# e2   NaN   NaN
# e3   NaN   NaN
# e4   NaN   NaN

# %%
df2 = pd.DataFrame([{"col1":1,"col2":2}], index=["e4"])
df3 = df1.add(df2, axis=1)
print(df3)
# Out:
#     col1  col2
# e1   NaN   NaN
# e2   NaN   NaN
# e3   NaN   NaN
# e4   NaN   NaN

# %%
df2 = pd.DataFrame([{"col1":1,"col2":2}], index=["e4"])
df3 = pd.concat([df1, df2])
print(df3)
# Out:
#       col1       col2
# e1  123.32  123.32432
# e2  456.34  456.34256
# e3  789.53  789.53425
# e4    1.00    2.00000

# %%
df2 = pd.DataFrame([{"col1":1,"col2":2,"col3":3}], index=["e4"])
df1 = pd.DataFrame(zip([123.32432,456.34256,789.53425],[123.32432,456.34256,789.53425]), index=["e1","e2","e3"], columns=['col1', 'col2'])
df3 = pd.concat([df1, df2])
print(df3)
# Out:
#          col1       col2  col3
# e1  123.32432  123.32432   NaN
# e2  456.34256  456.34256   NaN
# e3  789.53425  789.53425   NaN
# e4    1.00000    2.00000   3.0

# %%
df = pd.DataFrame([1,2,3], columns=["col1"], index=["a","b","c"])
print(df)
# Out:
#    col1
# a     1
# b     2
# c     3

# %%
df = pd.DataFrame([1,2,3,4], columns=["col1"], index=["a","b","c"])
print(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 df = pd.DataFrame([1,2,3,4], columns=["col1"], index=["a","b","c"])
#       2 print(df)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:867, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     859         mgr = arrays_to_mgr(
#     860             arrays,
#     861             columns,
#    (...)
#     864             typ=manager,
#     865         )
#     866     else:
# --> 867         mgr = ndarray_to_mgr(
#     868             data,
#     869             index,
#     870             columns,
#     871             dtype=dtype,
#     872             copy=copy,
#     873             typ=manager,
#     874         )
#     875 else:
#     876     mgr = dict_to_mgr(
#     877         {},
#     878         index,
#    (...)
#     881         typ=manager,
#     882     )
#
# ...

# %%
df = pd.DataFrame([1,2,3], columns=["col1"], index=["a","b","c","d"])
print(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 df = pd.DataFrame([1,2,3], columns=["col1"], index=["a","b","c","d"])
#       2 print(df)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:867, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     859         mgr = arrays_to_mgr(
#     860             arrays,
#     861             columns,
#    (...)
#     864             typ=manager,
#     865         )
#     866     else:
# --> 867         mgr = ndarray_to_mgr(
#     868             data,
#     869             index,
#     870             columns,
#     871             dtype=dtype,
#     872             copy=copy,
#     873             typ=manager,
#     874         )
#     875 else:
#     876     mgr = dict_to_mgr(
#     877         {},
#     878         index,
#    (...)
#     881         typ=manager,
#     882     )
#
# ...

# %%
import pandas as pd
import numpy as np
ar1 = np.array([1,1.2,"4"])
print(ar1.dtype)
# Out:
# <U32

# %%
import pandas as pd
import numpy as np
ar1 = np.array([1,1.2,"4",np.nan])
print(ar1.dtype)
print(ar1)
# Out:
# <U32
# ['1' '1.2' '4' 'nan']

# %%
import pandas as pd
import numpy as np
ar1 = np.array([1,1.2,"4",np.nan])
print(ar1.dtype)
print(ar1)

# %%
df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20130102"),
        "C": pd.Series(1, index=list(range(4)), dtype="float32"),
        "D": np.array([3] * 4, dtype="int32"),
        "E": pd.Categorical(["test", "train", "test", "train"]),
        "F": "foo",
    }
)

# %%
np.array([3] * 4, dtype="int32")
# Out:
# array([3, 3, 3, 3])

# %%
df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20130102"),
        "C": pd.Series(1, index=list(range(4)), dtype="float32"),
        "D": np.array([3] * 4, dtype="int32"),
        "E": pd.Categorical(["test", "train", "test", "train"]),
        "F": "foo",
    }
)

# %%
pd.Series(1, index=list(range(4)), dtype="float32")
# Out:
# 0    1.0
# 1    1.0
# 2    1.0
# 3    1.0
# dtype: float32

# %%
pd.Series([1,2], index=list(range(4)), dtype="float32")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 pd.Series([1,2], index=list(range(4)), dtype="float32")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:575, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     573     index = default_index(len(data))
#     574 elif is_list_like(data):
# --> 575     com.require_length_match(data, index)
#     577 # create/copy the manager
#     578 if isinstance(data, (SingleBlockManager, SingleArrayManager)):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\common.py:573, in require_length_match(data, index)
#     569 """
#     570 Check the length of data matches the length of the index.
#     571 """
#     572 if len(data) != len(index):
# --> 573     raise ValueError(
#     574         "Length of values "
#     575         f"({len(data)}) "
# ...

# %%
df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20130102"),
        "C": pd.Series(1, index=list(range(4)), dtype="float32"),
        "D": np.array([3] * 4, dtype="int32"),
        "E": pd.Categorical(["test", "train", "test", "train"]),
        "F": "foo",
    }
)
print(df2)
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
pd.Categorical(["test", "train", "test", "train"])
# Out:
# ['test', 'train', 'test', 'train']
# Categories (2, object): ['test', 'train']

# %%
d_ct = pd.Categorical(["test", "train", "test", "train"])
print(d_ct.index)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 2
#       1 d_ct = pd.Categorical(["test", "train", "test", "train"])
# ----> 2 print(d_ct.index)
#
# AttributeError: 'Categorical' object has no attribute 'index'

# %%
df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20130102"),
        "C": pd.Series(1, index=list(range(4)), dtype="float32"),#0,1,2,3
        "D": np.array([3] * 4, dtype="int32"),#0,1,2,3
        "E": pd.Categorical(["test", "train", "test", "train"]),
        "F": "foo",
    },
    index=range(5,9)
)
print(df2)
# Out:
#      A          B   C  D      E    F
# 5  1.0 2013-01-02 NaN  3   test  foo
# 6  1.0 2013-01-02 NaN  3  train  foo
# 7  1.0 2013-01-02 NaN  3   test  foo
# 8  1.0 2013-01-02 NaN  3  train  foo

# %%
pd.Series(pd.Timestamp("20130102"), index=list(range(4)))
# Out:
# 0   2013-01-02
# 1   2013-01-02
# 2   2013-01-02
# 3   2013-01-02
# dtype: datetime64[s]

# %%
df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20130102"),
        "C": pd.Series(1, index=list(range(4)), dtype="float32"),#0,1,2,3
        "D": np.array([3] * 4, dtype="int32"),#0,1,2,3
        "E": pd.Categorical(["test", "train", "test", "train"]),
        "F": "foo",
    },
    index=range(3,7)
)
print(df2)
# Out:
#      A          B    C  D      E    F
# 3  1.0 2013-01-02  1.0  3   test  foo
# 4  1.0 2013-01-02  NaN  3  train  foo
# 5  1.0 2013-01-02  NaN  3   test  foo
# 6  1.0 2013-01-02  NaN  3  train  foo

# %%
df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20130102"),
        "C": pd.Series(1, index=list(range(10)), dtype="float32"),#0,1,2,3
        "D": np.array([3] * 4, dtype="int32"),#0,1,2,3
        "E": pd.Categorical(["test", "train", "test", "train"]),
        "F": "foo",
    },
    index=range(2,6)
)
print(df2)
# Out:
#      A          B    C  D      E    F
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo
# 4  1.0 2013-01-02  1.0  3   test  foo
# 5  1.0 2013-01-02  1.0  3  train  foo

# %%
df2 = pd.DataFrame(
    {
        "A": 1.0,
        "C": pd.Series(1, index=list(range(4)), dtype="float32"),#0,1,2,3
        "D": np.array([3] * 4, dtype="int32"),#0,1,2,3
       
        "F": "foo",
    }
)
print(df2)
# Out:
#      A    C  D    F
# 0  1.0  1.0  3  foo
# 1  1.0  1.0  3  foo
# 2  1.0  1.0  3  foo
# 3  1.0  1.0  3  foo

# %%
df2 = pd.DataFrame(
    {
        "A": 1.0,
       
        "D": np.array([3] * 4, dtype="int32"),#0,1,2,3
       
        "F": "foo",
    }
)
print(df2.to_numpy())
# Out:
# [[1.0 3 'foo']
#  [1.0 3 'foo']
#  [1.0 3 'foo']
#  [1.0 3 'foo']]

# %%
df2 = pd.DataFrame(
    {
        "A": 1.0,
       
        "D": np.array([3] * 4, dtype="int32"),#0,1,2,3
       
        "F": "foo",
    }
)
ar2 = df2.to_numpy()
print(ar2)
print(ar2.dtype)
# Out:
# [[1.0 3 'foo']
#  [1.0 3 'foo']
#  [1.0 3 'foo']
#  [1.0 3 'foo']]
# object

# %%
ar2 = np.array([1,2,"3",4.5])
print(ar2)
print(ar2.dtype)
# Out:
# ['1' '2' '3' '4.5']
# <U32

# %%
a=pd.Timestamp("20130102")
print(str(a))
# Out:
# 2013-01-02 00:00:00

# %%
ar2 = np.array([1,2,"3",4.5,pd.Timestamp("20130102")])
print(ar2)
print(ar2.dtype)
# Out:
# [1 2 '3' 4.5 Timestamp('2013-01-02 00:00:00')]
# object

# %%
ar2 = np.array([1,2,"3",4.5,pd.Timestamp("20130102")])
print(ar2)
print(ar2.dtype)
print(max(ar2))
# Out:
# [1 2 '3' 4.5 Timestamp('2013-01-02 00:00:00')]
# object
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 4
#       2 print(ar2)
#       3 print(ar2.dtype)
# ----> 4 print(max(ar2))
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
ar2 = np.array([1,2,"3",4.5,pd.Timestamp("20130102")])
print(ar2)
print(ar2.dtype)
print(np.max(ar2))
# Out:
# [1 2 '3' 4.5 Timestamp('2013-01-02 00:00:00')]
# object
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 4
#       2 print(ar2)
#       3 print(ar2.dtype)
# ----> 4 print(np.max(ar2))
#
# File ~\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:2810, in max(a, axis, out, keepdims, initial, where)
#    2692 @array_function_dispatch(_max_dispatcher)
#    2693 @set_module('numpy')
#    2694 def max(a, axis=None, out=None, keepdims=np._NoValue, initial=np._NoValue,
#    2695          where=np._NoValue):
#    2696     """
#    2697     Return the maximum of an array or maximum along an axis.
#    2698
#    (...)
#    2808     5
#    2809     """
# -> 2810     return _wrapreduction(a, np.maximum, 'max', axis, None, out,
#    2811                           keepdims=keepdims, initial=initial, where=where)
#
# ...

# %%
df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20130102"),
        "C": pd.Series(1, index=list(range(10)), dtype="float32"),#0,1,2,3
        "D": np.array([3] * 4, dtype="int32"),#0,1,2,3
        "E": pd.Categorical(["test", "train", "test", "train"]),
        "F": "foo",
    },
    index=range(2,6)
)
print(df2)
print(df2.describe())
# Out:
#      A          B    C  D      E    F
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo
# 4  1.0 2013-01-02  1.0  3   test  foo
# 5  1.0 2013-01-02  1.0  3  train  foo
#          A                    B    C    D
# count  4.0                    4  4.0  4.0
# mean   1.0  2013-01-02 00:00:00  1.0  3.0
# min    1.0  2013-01-02 00:00:00  1.0  3.0
# 25%    1.0  2013-01-02 00:00:00  1.0  3.0
# 50%    1.0  2013-01-02 00:00:00  1.0  3.0
# 75%    1.0  2013-01-02 00:00:00  1.0  3.0
# max    1.0  2013-01-02 00:00:00  1.0  3.0
# std    0.0                  NaN  0.0  0.0

# %%
df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20130102"),
        "C": pd.Series(1, index=list(range(10)), dtype="float32"),#0,1,2,3
        "D": np.array([3] * 4, dtype="int32"),#0,1,2,3
        "E": pd.Categorical(["test", "train", "test", "train"]),
        "F": "foo",
    },
    index=range(2,6)
)
print(df2)
print(df2.describe())

# %%
str(pd.Timestamp("20130102"))
# Out:
# '2013-01-02 00:00:00'
